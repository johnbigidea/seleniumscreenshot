# %%
import time
from selenium import webdriver
from datetime import datetime
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import urllib.request as requests
from urllib.request import urlopen
import re
import random

r =  range(1,10000)
bloglist=[]
n=0
headers = {'User-Agent':'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0'}

for a in r:
    url = 'https://www.indeed.com/jobs?q=data+analyst+intern&start=' + str(a*10)
    print(url)
    req =  requests.Request(url,
                            data=None,
                            headers=headers)
    
    
    html = urlopen(url).read().decode('utf-8')


    soup = BeautifulSoup(html,features='lxml')
    sub_links = soup.find_all('a', {'href': re.compile('/i/.*?\.html')})
    for sub in sub_links:
        if sub['href'] in bloglist:
            continue
        else:
            bloglist.append(sub['href'])

for d in bloglist:
    url2= 'http://www.mafengwo.cn'+str(d)



        
    
    
    
    
    try:
        
        html2 = urlopen(url2).read().decode('utf-8')
        soup2 = BeautifulSoup(html2,features='lxml')
        img_links = soup2.find_all('img', {'data-src': re.compile('.*?\.jpeg')})
        name = soup2.find('meta',{'name':'author'})
        strname = str(name)
        match = re.search(r"(\d+),(.+)\" name",strname)
        print(match.group(2))
        file_a_n = match.group(2)
        
        try:
            people = soup2.find('li',{'class': 'people'})
            print(people)
            strpeople = str(people)
            speople = strpeople.split('</span>')[1].strip('</li>')
            print(speople)
        except:
            speople = 'none'
            
        try:

            time = soup2.find('li',{'class': 'time'})
            strtime = str(time)
            match2 = re.search(r"(\d+-\d+-\d+)",strtime)
            sdate = match2.group()
            print(sdate)
        except:
            sdate = 'none'
        try:
#             html2 = urlopen(url2).read().decode('utf-8')
#             soup2 = BeautifulSoup(html2,features='lxml')
            day = soup2.find('li',{'class': 'day'})
            print(day)
            strday = str(day)
            match3 = re.search(r"(\d+)",strday)
            sday = match3.group()
            print(sday)
        except:
            sday = 'none'
        try:
#             html2 = urlopen(url2).read().decode('utf-8')
#             soup2 = BeautifulSoup(html2,features='lxml')
            cost = soup2.find('li',{'class': 'cost'})
            print(cost)
            strcost = str(cost)
            match4 = re.search(r"(\d+)",strcost)
            scost = match4.group()
            print(scost)
        except:
            scost = 'none'

            
        for link in img_links:
            
            print(link['data-src'])
            content= urlopen(link['data-src']).read()
            with open(str(n)+'_'+file_a_n+'_'+sdate+'_'+sday+'_'+scost+'.jpeg','wb') as f:
                f.write(content)
                n+=1
    except:
        continue
# Out:
# <!DOCTYPE html><html xmlns="https://www.w3.org/1999/xhtml" xml:lang="en" lang="en" class="  is-js  js flexbox canvas canvastext webgl no-touch geolocation postmessage websqldatabase indexeddb hashchange history draganddrop websockets rgba hsla multiplebgs backgroundsize borderimage borderradius boxshadow textshadow opacity cssanimations csscolumns cssgradients cssreflections csstransforms csstransforms3d csstransitions fontface generatedcontent video audio localstorage sessionstorage webworkers applicationcache no-svg no-inlinesvg no-smil no-svgclippaths" style="touch-action: pan-y; -webkit-user-drag: none; -webkit-tap-highlight-color: rgba(0, 0, 0, 0);"><link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Roboto:100,300,400,500" /><head><script type="text/javascript" async="" src="https://www.gstatic.com/recaptcha/api2/v1526884278587/recaptcha__en.js"></script><script type="text/javascript" src="https://monster.demdex.net/event?d_nsid=0&amp;d_ld=_ts%3D1527325084496&amp;d_rtbd=json&amp;d_jsonv=1&amp;d_dst=1&amp;d_cb=demdexRequestCallback_monster_0_1527325084496&amp;c_pageName=desktop%7Cmons%7Clpf%7Cjobsearch-trovix-cloud&amp;c_channel=58&amp;c_events=event73%2Cevent3%2Cevent74%3D23&amp;c_prop1=D%3Dg&amp;c_eVar1=D%3Dg&amp;c_eVar2=unrecognized&amp;c_eVar4=0&amp;c_prop22=N%2FA-Cloud&amp;c_prop23=N%2FA-Cloud&amp;c_prop24=1%2F1%2F0001%2012%3A00%3A00%20AM&amp;c_prop25=N%2FA-Cloud&amp;c_eVar25=401459ea-3053-4b7d-9bfd-925f185ef2fc&amp;c_prop26=N%2FA-Cloud&amp;c_eVar26=Unspecified_CHRISTUS%20Health&amp;c_eVar27=N%2FA-Cloud&amp;c_eVar28=IT%2FSoftware%20Development&amp;c_eVar29=N%2FA-Cloud&amp;c_eVar31=Texarkana%2C%20TX%2075503&amp;c_prop32=JV_new&amp;c_eVar32=N%2FA-Cloud&amp;c_eVar35=CHRISTUS%20Health&amp;c_eVar36=App_Cstm&amp;c_eVar37=N%2FA-Cloud&amp;c_eVar38=U%2FL-Apply&amp;c_eVar47=17056&amp;c_eVar48=Not%20Specified&amp;c_eVar50=PPC&amp;c_eVar53=1300087001001&amp;c_eVar57=no%20branding&amp;c_eVar66=Monster&amp;c_prop74=23&amp;c_prop75=m1"></script><script src="https://www.google-analytics.com/analytics.js"></script><script src="https://secure.quantserve.com/aquant.js?a=p-7fziOTiEM1bCE"></script><script src="https://connect.facebook.net/signals/config/453920968151817?v=2.8.14&amp;r=stable" async=""></script><script src="https://connect.facebook.net/signals/config/10153704765005649?v=2.8.14&amp;r=stable" async=""></script><script src="https://connect.facebook.net/en_US/fbevents.js"></script><script src="https://sb.scorecardresearch.com/beacon.js"></script><script type="text/javascript" src="https://monster.demdex.net/event?d_nsid=0&amp;d_ld=_ts%3D1527325084292&amp;d_rtbd=json&amp;d_jsonv=1&amp;d_dst=1&amp;d_cb=demdexRequestCallback_monster_0_1527325084292&amp;c_pageName=desktop%7Cmons%7Clpf%7Cjobsearch-trovix-cloud&amp;c_channel=58&amp;c_events=event1%2Cevent27%2Cevent74%3D23&amp;c_prop1=D%3Dg&amp;c_eVar1=D%3Dg&amp;c_eVar2=unrecognized&amp;c_eVar4=0&amp;c_prop16=Unspecified&amp;c_eVar16=trovix-cloud&amp;c_prop17=Unspecified&amp;c_eVar17=Unspecified&amp;c_prop18=Unspecified&amp;c_eVar18=Unspecified&amp;c_prop19=Unspecified&amp;c_eVar19=data%20analyst&amp;c_eVar20=Unspecified&amp;c_eVar21=Unspecified&amp;c_eVar22=Unspecified&amp;c_eVar23=1001%2B&amp;c_eVar24=6&amp;c_eVar43=Cloud%20Search%20Y&amp;c_eVar73=bolded-9_logo-0_bolded-logo-0_regular-141&amp;c_prop74=23&amp;c_prop75=m1"></script><script type="text/javascript" async="" src="//platform.twitter.com/oct.js"></script><script type="text/javascript" async="" src="//www.googleadservices.com/pagead/conversion_async.js"></script><script async="" src="https://s.pinimg.com/ct/core.js"></script><script type="text/javascript" async="async" src="https://newjobs.d1.sc.omtrdc.net/id?callback=s_c_il%5B1%5D._setAnalyticsFields&amp;mcorgid=A86C525A548992260A4C98C6%40AdobeOrg&amp;mid=10159717637422987882702328904958391531"></script><script src="https://asset.pagefair.net/ads.min.js"></script><script src="https://asset.pagefair.com/measure.min.js"></script><script type="text/javascript ...
#
# <meta http-equiv="X-UA-Compatible" content="IE=8, IE=9, IE=10" />
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta http-equiv="Expires" content="0" />
# <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=2.0, minimum-scale=1" />
# <meta charset="utf-8" />
# <title>Data Analyst Jobs | Monster.com</title>
#
#         <script async="" src="//www.googletagmanager.com/gtm.js?id=GTM-NQK2FJ"></script><script>
#         var cb = function () {
#             var l = document.createElement('link'); l.rel = 'stylesheet';
#             l.href = 'https://fonts.googleapis.com/css?family=Roboto:100,300,400,500';
#             var h = document.getElementsByTagName('head')[0]; h.parentNode.insertBefore(l, h);
#         };
#         var raf = requestAnimationFrame || mozRequestAnimationFrame ||
#         webkitRequestAnimationFrame || msRequestAnimationFrame;
#         if (raf) raf(cb);
#         else window.addEventListener('load', cb);
#         </script>
#
# <!--[if IE 8]>
#       <link rel="stylesheet" type="text/css" href="https://securemedia.newjobs.com/niche/css/generic-template/style-ie.css" />
# <![endif]-->
#
# <!--[if lt IE 9]>
# <script src="https://securemedia.newjobs.com/niche/js/html5shim.js"></script>
# <script src="/siteassets/scripts/respond.js" type="text/javascript"></script>
# <![endif]-->
#
#     <script src="https://oas.monster.com/Scripts/oas_analytics.js" type="text/javascript"></script>
#
#
#     <link rel="canonical" href="https://www.monster.com/jobs/q-data-analyst-jobs.aspx" />
# <link id="favIcon" runat="server" rel="shortcut icon" href="https://securemedia.newjobs.com/favicon.ico" />
# <meta name="description" content="Explore more than 1,000 Data Analyst jobs in the United-States. Browse by location or industry. Find the right position and build your career." />
# <meta name="keywords" content="Data Analyst jobs, Data Analyst career resources, Data Analyst careers, Data Analyst job, Data Analyst career, Data Analyst employment, Data Analyst work, Data Analyst job opportunities, Data Analyst employment opportunities, jobs in Data Analyst, careers in Data Analyst" />
# <meta name="SL.domain" content="login.monster.com" />
# <meta name="SL.channelAlias" content="MONS" />
#     <meta content="Data Analyst Jobs | Monster.com" property="og:title" />
#     <meta content="website" property="og:type" />
#     <meta content="https://www.monster.com/jobs/search/?q=data-analyst&amp;intcid=skr_navigation_nhpso_searchMain&amp;jobid=401459ea-3053-4b7d-9bfd-925f185ef2fc&amp;stpage=1&amp;page=6" property="og:url" />
#     <meta content="https://securemedia.newjobs.com/id/lpf20/CORE/icon-50-m.png" property="og:image" />
#     <meta content="Monster" property="og:site_name" />
#     <meta content="Explore more than 1,000 Data Analyst jobs in the United-States. Browse by location or industry. Find the right position and build your career." property="og:description" />
#     <meta content="Data Analyst Jobs | Monster.com" itemprop="name" />
#     <meta content="Explore more than 1,000 Data Analyst jobs in the United-States. Browse by location or industry. Find the right position and build your career." itemprop="description" />
#     <meta content="https://securemedia.newjobs.com/id/lpf20/CORE/icon-50-m.png" itemprop="image" />
#     <link rel="prev" href="https://www.monster.com/jobs/search/?q=data-analyst&amp;intcid=skr_navigation_nhpso_searchMain&amp;stpage=1&amp;page=5" />
#     <link rel="next" href="https://www.monster.com/jobs/search/?q=data-analyst&amp;intcid=skr_navigation_nhpso_searchMain&amp;stpage=1&amp;page=7" />
#     <script>
#         window.MONS_LOCALES = {
#             coda: {
#                 images: 'https://coda.newjobs.com/Assets/MUX/JaJobViewCloud/2018.06.0.476/img/'
#             }
#         }
#         window.onMsgsReady = function (msgs) {
#             window.MONS_LOCALES.msg = msgs;
#         };
#     </script>
#     <script type="text/javascript" src="https://coda.newjobs.com/Assets/MUX/CoreLpf20/2018.05.0.17/msgset;MONS/app.lpf20.ids?callback=onMsgsReady"></script>
#     <script type="text/javascript" src="https://coda.newjobs.com/Assets/MUX/CoreLpf20/2018.05.0.17/js/app.lpf20.bundle.js"></script>
#     <script type="text/javascript" src="https://coda.newjobs.com/Assets/MUX/JaJobViewCloud/2018.06.0.476/js/app.js30.bundle.js"></script>
#         <link href="https://css-seeker.newjobs.com/MONS/v4.1.2.2/js30_css.axd?s=1" type="text/css" rel="stylesheet" />
#         <script type="text/javascript" src="https://js-seeker.newjobs.com/MONS/v4.1.2.5/js30_js.axd?s=1"></script>
#     <link rel="stylesheet" href="https://coda.newjobs.com/Assets/MUX/CoreLpf20/2018.05.0.17/css/app.lpf20.css" />
#     <link rel="stylesheet" href="https://coda.newjobs.com/Assets/MUX/JaJobViewCloud/2018.06.0.476/css/app.js30.css" />
#
#     <link rel="stylesheet" type="text/css" href="https://securemedia.newjobs.com/global/ps/materialdesignicons.min.css" media="all" />
#
#
#
#
#
# <meta content="Monster" name="m_impr.a_affiliate_id" /><meta content="q=data%20analyst&amp;brd=1&amp;brd=2&amp;cy=US&amp;pg=6&amp;pp=150&amp;sort=rv.di.dt&amp;nosal=true&amp;stp=ScoreFenceMain" name="m_impr.s_search_query" />
# <meta content="Data Analyst" name="m_impr.s_q" />
# <meta content="6" name="m_impr.j_pg" />
#
#
#
#
#
#
# <script type="text/javascript" src="//nexus.ensighten.com/monster/Bootstrap.js"></script>
#
#
#
#
#
# <meta name="debugInfo" content="&#10;" />
#     <script type="text/javascript">
#        var inHeadTS = (new Date()).getTime();
#     </script>
#         <script type="text/javascript">
#         var navResult = {"Result":{"ChannelId":58,"ChannelAlias":"MONS","NavHeader":null,"NavFooter":null},"Status":"Success","ErrorDetails":"Success","ErrorGuid":""};
#         if (navResult.Result.NavHeader != null) {
#             document.write ("&lt;link rel='stylesheet' type='text/css' href='https://securemedia.newjobs.com/global/css/www/newspaper-nav/newspaper-nav.css' /&gt;");
#             document.write("&lt;style&gt;.mainbar .matter{margin-top: 0;} .logo-newspaper {background: url('" + navResult.Result.NavHeader.NpLogoImageUrl + "') no-repeat scroll center center / contain} .jobAlertButton {top:112px} @media (max-width: 767px) { .logo-newspaper {height: 50px; margin-left:0;} .navbar.solid-nav .navbar-text.login-btn {margin-top: 8px;} .navbar .navbar-toggle.search-btn-container {margin: 7px 0 0;} body {margin-top: 146px !important;} .jobAlertButton {top: 120px;} }&lt;/style&gt;");
#         }
#     </script>
#
#     <script type="application/ld+json">
#         {
#         "@context" : "http://schema.org",
#         "@type" : "Organization",
#         "name" : "Monster",
#         "url" : "https://www.monster.com",
#         "logo" : "https://media.newjobs.com/global/img/header-m.png",
#         "sameAs" : [ "https://twitter.com/Monster", "https://www.facebook.com/monster", "https://plus.google.com/+monster", "https://www.youtube.com/monster", "https://instagram.com/monster"]
#         }
#     </script>
# <script type="text/javascript" async="" src="https://s.dpmsrv.com/dpm_2a2b47bf21a372f267deccbb420567f3d450b3c0.min.js"></script><script src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/860438031/?random=1527325084346&amp;cv=9&amp;fst=1527325084346&amp;num=1&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;u_h=600&amp;u_w=800&amp;u_ah=600&amp;u_aw=800&amp;u_cd=24&amp;u_his=2&amp;u_tz=-240&amp;u_java=false&amp;u_nplug=0&amp;u_nmime=0&amp;sendb=1&amp;frm=0&amp;url=https%3A%2F%2Fwww.monster.com%2Fjobs%2Fsearch%2F%3Fq%3Ddata-analyst%26intcid%3Dskr_navigation_nhpso_searchMain%26jobid%3D401459ea-3053-4b7d-9bfd-925f185ef2fc%26stpage%3D1%26page%3D6&amp;tiba=Data%20Analyst%20Jobs%20%7C%20Monster.com&amp;async=1&amp;rfmt=3&amp;fmt=4"></script><iframe frameborder="0" height="0" marginheight="0" marginwidth="0" scrolling="no" src="https://secure.jdn.monster.com/render/nano.aspx?e6d8f931-8e1b-4f5b-8bcf-92f28bee89e2~0~0~1527325084579~240~https%3A//www.monster.com/jobs/search/%3Fq%3Ddata-analyst%26intcid%3Dskr_navigation_nhpso_searchMain%26jobid%3D401459ea-3053-4b7d-9bfd-925f185ef2fc%26stpage%3D1%26page%3D6%26JobID%3D0" width="0" style="visibility: hidden;"></iframe></head>
# <body>
# <script type="text/javascript" language="javascript">var DYNAMIC_S_ACCOUNT='newjobsProdSeekerUS';var DYNAMIC_S_CURRENCYCODE='USD';</script><script type="text/javascript">//&lt;![CDATA[
# var amc=amc||{};if(!amc.on){amc.on=amc.call=function(){}};
# document.write("&lt;scr"+"ipt defer type='text/javascript' src='https://securemedia.newjobs.com/js/sc/sitecatalystloadtimeLL.js'&gt;&lt;/sc"+"ript&gt;");
# //]]&gt;
# _m.ATM.properties={"eVar2":"unrecognized","channel":"58","eVar1":"D=g","prop1":"D=g","eVar4":"0","eVar17":"Unspecified","eVar16":"trovix-cloud","eVar23":"1001+","eVar19":"data analyst","eVar24":"6","eVar18":"Unspecified","events.event1":"jobsearch","eVar20":"Unspecified","list2":"Unspecified","list1":"Unspecified","eVar21":"Unspecified","prop16":"Unspecified","prop17":"Unspecified","prop18":"Unspecified","prop19":"Unspecified","eVar22":"Unspecified","events.event27":"true","eVar73":"bolded-9_logo-0_bolded-logo-0_regular-141","list3":"ViewSplit_NewCardView,EmptySearchSplit_Default,BAMLiteSplit_Default,QualifyingTagsSplit_Control,TypeaheadElasticSearchSplit_NewElasticSearch,SalaryDisplaySplit_Default,SavedJobsSplit_Default,JobSearchJobViewHybridSplit_JobSearchJobViewHybridView,JobSearchJobViewPureSplit_JobSearchJobViewPureView","eVar43":"Cloud Search Y"};_m.ATM.pageName='desktop|mons|lpf|jobsearch-trovix-cloud';_m.ATM.version=0;_m.ATM.appID='lpf';_m.ATM.channelID=58;_m.ATM.countryID=164;_m.ATM.appConfig={version:'0',appID:'lpf',channelID:'58',countryID:'164'};_m.ATM.runOnLoad=true;
# (function () {if (typeof _m.ATM.initFromOnReady === 'function') {_m.ATM.initFromOnReady();} else {setTimeout(function () {if (typeof _m.ATM.initFromOnReady === 'function') {_m.ATM.initFromOnReady();} else {$(document).ready(_m.ATM.initFromOnReady);}}, 200);}})();</script><script defer="" type="text/javascript" src="https://securemedia.newjobs.com/js/sc/sitecatalystloadtimeLL.js"></script>
#
# <!-- Google Tag Manager -->
# <noscript>&lt;iframe src="//www.googletagmanager.com/ns.html?id=GTM-NQK2FJ"
# height="0" width="0" style="display:none;visibility:hidden"&gt;&lt;/iframe&gt;</noscript>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&amp;l='+l:'';j.async=true;j.src=
# '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-NQK2FJ');</script>
# <!-- End Google Tag Manager -->
#
# <div style="display:none;"></div>
#     <!-- start of markup for nano ad -->
#
#     <script type="text/javascript" language="JavaScript">
#         $(function () {
#             _s.lpf.canTrack.trackI();
#         });
#     </script>
#
# <!-- end of markup for nano ad -->
#
#
#
#
#
#
#
#
#     <div class="page-layout">
#         <div id="headerWidget">
#
#
# <input type="hidden" id="AcceptCookies" value="True" />
#
# <input type="hidden" id="lpfDomainPath" value="https://www.monster.com/jobs" />
# <input type="hidden" id="servicesDomainPath" value="https://www.monster.com/jobs" />
# <input type="hidden" id="inboxLink" value="https://www.monster.com/message/inbox" />
# <input type="hidden" id="countryId" value="164" />
# <input type="hidden" id="showLocationTypeAheadTrovix" value="True" />
# <input type="hidden" id="showLocationTypeAheadLucene" value="False" />
# <input type="hidden" id="showKeywordTypeAheadTrovix" value="True" />
# <input type="hidden" id="isLoggedIn" value="False" />
# <input type="hidden" id="isOnlyRecognized" value="False" />
# <input type="hidden" id="successMessage" value="You have no new messages." />
# <input type="hidden" id="cookieName" value="hdCookiesIM" />
# <input type="hidden" id="cookieValue" value="0" />
# <input type="hidden" id="cookieExpirationTime" value="365" />
# <input type="hidden" id="cookieDomain" value=".monster.com" />
# <input type="hidden" id="searchPageAction" value="https://www.monster.com/jobs/search/" />
# <input type="hidden" id="mcMainBox" class="mc-mail-box" value="" />
# <input type="hidden" id="mcAwsUrl" value="" />
#
# <input type="hidden" id="countryCode" value="US" />
# <input type="hidden" id="languageCode" value="EN" />
# <input type="hidden" id="typeAheadRequestUrl" value="https://c6v0t0t861.execute-api.us-east-1.amazonaws.com/Prod/vulcantypeaheadresource?matchString=%Q&amp;countrycode={0}&amp;languagecode={1}&amp;fuzziness=0" />
# <input type="hidden" id="esTypeaheadEnabled" value="True" />
# <input type="hidden" id="msgKeywords" value="Key Words" />
# <input type="hidden" id="msgJobTitles" value="Job Titles" />
# <input type="hidden" id="msgCompanyNames" value="Company Names" />
# <input type="hidden" id="isRedirectionToNoCriteriaPageEnabled" value="true" />
# <input type="hidden" id="noCriteriaPagePrefix" value="nocriteria" />
#
#
# <div id="pv_nav-fixed">
#
#     <a href="#mainContent" class="skip-main">Skip to main content</a>
#
#
#     <!-- Top Nav -->
#         <nav class="solid-nav navbar-2 navbar navbar-default navbar-fixed-top" role="banner" id="jsrHeader">
#             <div style="display: none" class="interMsgsW cookie-msg">
#                 <div class="interMsgsPar">
#                     <div class="interMsg">
#                         <a onclick="return false;" name="closeIMEmployer" href="#" class="close-msg" title="Don't display this message again">
#                             <span class="dontDisplay">Don't display this message again</span>
#                             <span class="counter"></span><span class="fa fa-times"></span>
#                         </a>
#                         <h4>A Note About Cookies</h4>
#
#                     </div>
#                 </div>
#             </div>
#             <div class="container-fluid navbar-main">
#                 <!-- Brand and toggle get grouped for better mobile display -->
#                 <div id="mobile-navbar" class="navbar-header">
#                     <a class="navbar-brand" href="https://www.monster.com" aria-label="Monster Home">
#                         <div class="logo"> </div>
#                     </a>
#                     <!-- End Monster Logo -->
#                     <!-- Buttons in reverse order for Bootstrap -->
#                     <!-- New "Trigger" classes on buttons for JS (transitions.closeDropdowns()) -->
#                     <button type="button" class="navbar-toggle nav-trigger action action--open" aria-haspopup="true" aria-expanded="false" role="menu" data-target-menu="ml-menu">
#                         <span class="sr-only">Toggle Navigation Mobile</span>
#                         <span class="icon-bar"></span>
#                         <span class="icon-bar"></span>
#                         <span class="icon-bar"></span>
#                     </button>
#                     <!-- End Hamburger Button -->
#                     <button type="button" class="navbar-toggle navbar-toggle-account account-trigger action action--open-2 hidden-sm hidden-md hidden-lg" aria-haspopup="true" aria-expanded="false" role="menu" data-target-menu="ml-menu-2">
#                         <span class="sr-only">Toggle Account Navigation</span>
#                             <span class="navbar-profile-icon center-block"></span>
#                         <span class="emailCount"></span>
#                         <span class="logged-name">Account</span>
#                     </button>
#                     <!-- End Account Button -->
#                     <button type="button" class="navbar-toggle search-btn-container search-trigger" data-toggle="collapse" data-target="#mobile-navbar-search" aria-haspopup="true" aria-expanded="false" role="search">
#                         <i class="fa fa-search"></i>
#                         <span class="navbar-text">Jobs</span>
#                     </button>
#                     <!-- End Search Button -->
#                 </div>
#                 <!-- End Mobile Header/Navbar -->
#                 <div class="collapse navbar-collapse text-center" id="mobile-navbar-search" style="max-height: 523px;">
#                     <!-- End Navbar Right, Login, Signup, & Employer Links -->
#                     <form id="quickJobSearch" role="search" class="navbar-form" method="get">
#                         <div class="form-group top-search keywords">
#                             <div class="input-group input-group-sm">
#                                 <span class="input-group-addon"><i class="mdi mdi-magnify"></i></span>
#                                     <div id="multiple-datasets">
#                                         <label for="TypeHint" class="sr-only">Keywords</label>
#                                         <label for="keywords2" class="sr-only">Keywords</label>
#                                         <span class="twitter-typeaheadR" style="position: relative; display: inline-block;"><input type="text" class="form-control typeaheadR tt-hint hasclear" role="combobox" aria-expanded="false" aria-autocomplete="both" value="data analyst" readonly="" autocomplete="off" spellcheck="false" tabindex="-1" id="TypeHint" dir="ltr" style="position: absolute; top: 0px; left: 0px; border-color: transparent; box-shadow: none; opacity: 1; background: none 0% 0% / auto repeat scroll padding-box border-box rgba(0, 0, 0, 0);" /><input type="text" class="form-control typeaheadR tt-hint hasclear tt-input" role="combobox" aria-expanded="false" aria-autocomplete="both" placeholder="Search for Jobs" id="keywords2" name="q" value="data analyst" autocomplete="off" spellcheck="false" dir="auto" style="position: relative; vertical-align: top; background-color: transparent;" /><pre aria-hidden="true" style="position: absolute; visibility: hidden; white-space: pre; font-family: Roboto, Helvetica, Arial, sans-serif; font-size: 12px; font-style: normal; font-variant: normal; font-weight: 400; word-spacing: 0px; letter-spacing: 0px; text-indent: 0px; text-rendering: auto; text-transform: none;"></pre><div class="tt-menu" style="position: absolute; top: 100%; left: 0px; z-index: 100; display: none;"><div class="tt-dataset tt-dataset-Key-Words"></div></div></span>
#                                         <input type="hidden" id="typeaheadvalues" value="" />
#                                     </div>
#                                 <span class="input-clear" style="display: none;">x</span>
#                             </div>
#                         </div>
#                         <div class="form-group top-search location">
#
#                             <div class="input-group input-group-sm">
#                                 <span class="input-group-addon"><i class="mdi mdi-map-marker"></i></span>
#                                 <label for="location" class="sr-only">Location</label>
#                                 <span class="twitter-typeahead" style="position: relative; display: inline-block; direction: ltr;"><input type="text" autocomplete="off" id="location" name="where" role="combobox" aria-expanded="false" aria-autocomplete="both" class="form-control input-sm typeahead hasclear tt-input" placeholder="Location" value="" spellcheck="false" dir="auto" style="position: relative; vertical-align: top;" /><pre aria-hidden="true" style="position: absolute; visibility: hidden; white-space: pre; font-family: Roboto, Helvetica, Arial, sans-serif; font-size: 12px; font-style: normal; font-variant: normal; font-weight: 400; word-spacing: 0px; letter-spacing: 0px; text-indent: 0px; text-rendering: auto; text-transform: none;"></pre><span class="tt-dropdown-menu" style="position: absolute; top: 100%; left: 0px; z-index: 100; display: none; right: auto;"><div class="tt-dataset-0"></div></span></span>
#                                 <span class="input-clear" style="display: none;">x</span>
#                             </div>
#                         </div>
#                         <button onclick="InitializeGlobalheaderSearch(); return false;" class="btn btn-white btn-sm" type="button" id="doQuickSearch">Search</button>
#                             <div class="tm-wrap">
#                                 <input class="tm-input hidden" type="hidden" maxlength="200" /><input type="hidden" name="hiddenTagListA" id="keywords" />
#                             </div>
#                     </form>
#
#                     <!-- End Search Form (Desktop & Mobile) -->
#                     <ul class="nav navbar-nav navbar-right hidden-xs">
#                         <li class="dropdown account-dropdown">
#                             <a href="#" class="dropdown-toggle navbar-icon-link loginLink2" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">
#                                 <span class="sr-only">Toggle Account Navigation</span>
#                                     <span class="navbar-profile-icon center-block"></span>
#                                 <span class="emailCount"></span>
#                                 <span>Account</span>
#                             </a>
#                             <ul class="dropdown-menu">
#                                     <li>
#                                         <a href="https://login20.monster.com/?r=https%3a%2f%2fwww.monster.com%2fjobs%2fsearch%2f%3fq%3ddata-analyst%26intcid%3dskr_navigation_nhpso_searchMain%26jobid%3d401459ea-3053-4b7d-9bfd-925f185ef2fc%26stpage%3d1%26page%3d6&amp;ch=MONS" gfltrack="1">Log In</a>
#                                     </li>
#                                     <li>
#                                         <a href="https://login20.monster.com/Become-Member/Create-Account?r=https%3a%2f%2fwww.monster.com%2fjobs%2fsearch%2f%3fq%3ddata-analyst%26intcid%3dskr_navigation_nhpso_searchMain%26jobid%3d401459ea-3053-4b7d-9bfd-925f185ef2fc%26stpage%3d1%26page%3d6&amp;landedFrom=Header&amp;ch=MONS" gfltrack="1">Sign Up</a>
#                                     </li>
#                             </ul>
#                         </li>
#                             <li>
#                                 <div id="login-btn-employer">
#                                     <a href="https://hiring.monster.com/?intcid=skr_LPF_TopNav_Employer&amp;ch=MONS" title="">
#                                         Employers<br />
#                                         <span>Post Jobs &amp; Find Talent </span>
#                                     </a>
#                                 </div>
#                             </li>
#                     </ul>
#                 </div>
#             </div>
#             <div class="container-fluid subnav top-subnav hidden-xs" role="navigation">
#                 <ul class="nav navbar-nav hidden-xs subnav-nav clearfix">
#                             <li id="main-nav-0" class="dropdown">
#                                 <a href="#" class="dropdown-toggle" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">
#                                     Find Jobs <span class="caret"></span>
#                                 </a>
#                                 <ul class="dropdown-menu">
#
#             <li id="sub-nav-0">
#                 <a href="https://www.monster.com/jobs/advanced-search">Advanced Search</a>
#             </li>
#             <li id="sub-nav-1">
#                 <a href="https://www.monster.com/jobs/">Browse Jobs</a>
#             </li>
#
#
#                                 <li class="cmsNavContainer dropdown-sub"><a href="#" class="dropdown-toggle" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">Most Popular Jobs <span class="caret"></span></a><ul class="dropdown-menu dropdown-menu-sub"><li><a href="https://www.monster.com/jobs/q-courier-jobs.aspx">Courier Jobs</a></li><li><a href="https://www.monster.com/jobs/q-delivery-driver-jobs.aspx">Delivery Driver Jobs</a></li><li><a href="https://www.monster.com/jobs/q-dental-assistant-jobs.aspx">Dental Assistant Jobs</a></li><li><a href="https://www.monster.com/jobs/q-electrician-jobs.aspx">Electrician Jobs</a></li><li><a href="https://www.monster.com/jobs/q-medical-assistant-jobs.aspx">Medical Assistant Jobs</a></li><li><a href="https://www.monster.com/jobs/q-truck-driver-jobs.aspx">Truck Driver Jobs</a></li><li><a href="https://www.monster.com/jobs/q-pharmacist-jobs.aspx">Pharmacist Jobs</a></li><li><a href="https://www.monster.com/jobs/q-pharmacy-technician-jobs.aspx">Pharmacy Technician Jobs</a></li><li><a href="https://www.monster.com/jobs/q-receptionist-jobs.aspx">Receptionist Jobs</a></li><li><a href="https://www.monster.com/jobs/q-security-guard-jobs.aspx">Security Guard Jobs</a></li></ul></li></ul>
#                             </li>
#                             <li id="main-nav-1" class="dropdown">
#                                 <a href="#" class="dropdown-toggle" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">
#                                     Career Resources <span class="caret"></span>
#                                 </a>
#                                 <ul class="dropdown-menu">
#
#             <li id="sub-nav-2">
#                 <a href="https://www.monster.com/career-advice">Career Advice</a>
#             </li>
#             <li id="sub-nav-3">
#                 <a href="https://www.monster.com/salary">Salary</a>
#             </li>
#             <li id="sub-nav-4">
#                 <a href="http://career-services.monster.com/">Career Services</a>
#             </li>
#             <li id="sub-nav-5">
#                 <a href="https://www.monster.com/communities">Communities</a>
#             </li>
#             <li id="sub-nav-6">
#                 <a href="https://www.monster.com/career-advice/news">Employment News</a>
#             </li>
#
#
#                                 <li class="cmsNavContainer dropdown-sub"><a href="#" class="dropdown-toggle" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">Additional Resources <span class="caret"></span></a><ul class="dropdown-menu dropdown-menu-sub"><li><a href="https://www.monster.com/career-advice/cover-letter-resume">Cover Letters &amp; Resumes</a></li><li><a class="ext" href="https://www.monster.com/career-advice/job-interview">Interviewing Tips</a></li><li><a href="https://www.monster.com/career-advice/salary-benefits">Salary &amp; Benefits</a></li><li><a href="https://www.monster.com/career-advice/career-path">Career Paths</a></li><li><a href="https://www.monster.com/career-advice/workplace">Workplace Advice</a></li><li><a href="https://www.monster.com/career-advice/professional-development">Professional Development</a></li><li><a href="http://resources.monster.com/diversity-inclusion/work/">Diversity Resources</a></li></ul></li></ul>
#                             </li>
#                             <li id="main-nav-2">
#                                 <a href="https://www.monster.com/resumes/post-resume2?landedFrom=Header">Post a Resume
# </a>
#                             </li>
#                             <li id="main-nav-3">
#                                 <a href="https://www.monster.com/company">Company Profiles</a>
#                             </li>
#                 </ul>
#
#             </div>
#             <!-- End Main Nav or "Subnav" (Desktop)-->
#             <!-- Slideout Menu Container -->
#             <div class="container">
#
#                 <!-- Menu -->
#                 <nav id="ml-menu-2" class="menu"><nav class="menu__breadcrumbs"><a></a></nav>
#                     <!-- Close button for mobile version -->
#                     <button class="action action--close-2" aria-label="Close Menu">×</button>
#                     <div class="menu__wrap">
#                         <ul data-menu="main" class="menu__level menu__level--current">
#                                 <li class="menu__item">
#                                     <a class="menu__link" role="menuitem" href="https://login20.monster.com/?r=https%3a%2f%2fwww.monster.com%2fjobs%2fsearch%2f%3fq%3ddata-analyst%26intcid%3dskr_navigation_nhpso_searchMain%26jobid%3d401459ea-3053-4b7d-9bfd-925f185ef2fc%26stpage%3d1%26page%3d6&amp;ch=MONS" title="" gfltrack="1">Log In</a>
#                                 </li>
#                                 <li class="menu__item">
#                                     <a class="menu__link" role="menuitem" href="https://login20.monster.com/Become-Member/Create-Account?r=https%3a%2f%2fwww.monster.com%2fjobs%2fsearch%2f%3fq%3ddata-analyst%26intcid%3dskr_navigation_nhpso_searchMain%26jobid%3d401459ea-3053-4b7d-9bfd-925f185ef2fc%26stpage%3d1%26page%3d6&amp;landedFrom=Header&amp;ch=MONS" title="" gfltrack="1">Sign Up</a>
#                                 </li>
#                         </ul>
#                     </div>
#                 </nav>
#             </div>
#             <!-- End Main Container for Mobile Main Nav -->
#             <!-- Main container -->
#             <div class="container">
#                 <!-- Menu -->
#                 <!-- Mobile Left Nav -->
#                 <nav id="ml-menu" class="menu"><nav class="menu__breadcrumbs" aria-label="Navigation Breadcrumb"><a>all</a></nav>
#                     <!-- Close button for mobile version -->
#                     <button class="action action--close" aria-label="Close Menu">×</button>
#                     <!-- Edit contents of Init Crumb 1 to edit first breadcrumb in left slidout menu. -->
#                     <span id="init-crumb-1" style="display: none; visibility: hidden;">all</span>
#                     <!-- Menu contents. -->
#                     <div id="ml-menu-container" class="menu__wrap">
#                         <ul data-menu="main" class="menu__level menu__level--current">
#                             <li id="mobile-nav-home" class="menu__item">
#                                     <a class="menu__link" role="menuitem" href="https://www.monster.com">Home</a>
#                             </li>
#                                     <li id="mobile-nav-0" class="menu__item">
#                                         <a class="menu__link" role="menuitem" data-submenu="submenu-0" href="#" aria-haspopup="true" aria-expanded="false">Find Jobs</a>
#
#                                     </li>
#                                     <li id="mobile-nav-1" class="menu__item">
#                                         <a class="menu__link" role="menuitem" data-submenu="submenu-1" href="#" aria-haspopup="true" aria-expanded="false">Career Resources</a>
#
#                                     </li>
#                                     <li id="mobile-nav-2" class="menu__item">
#                                         <a class="menu__link" role="menuitem" href="https://www.monster.com/resumes/post-resume2?landedFrom=Header">Post a Resume
# </a>
#                                     </li>
#                                     <li id="mobile-nav-3" class="menu__item">
#                                         <a class="menu__link" role="menuitem" href="https://www.monster.com/company">Company Profiles</a>
#                                     </li>
#
#
#                         </ul>
#                     <ul data-menu="submenu-0" class="menu__level">
#
#     <li id="mobile-subnav-0" class="menu__item">
#         <a class="menu__link" href="https://www.monster.com/jobs/advanced-search" role="menuitem">Advanced Search</a>
#     </li>
#     <li id="mobile-subnav-1" class="menu__item">
#         <a class="menu__link" href="https://www.monster.com/jobs/" role="menuitem">Browse Jobs</a>
#     </li>
#     <li id="mobile-subnav-" class="menu__item">
#         <a class="menu__link" data-submenu="submenu-cms-109" href="#" aria-haspopup="true" aria-expanded="false" role="menuitem">Most Popular Jobs</a>
#
#     </li>
#
#                                         </ul><ul data-menu="submenu-cms-109" data-sub-for="109" class="menu__level cms-submenu">
#
#
#         <li class="menu__item"><a href="https://www.monster.com/jobs/q-courier-jobs.aspx" class="menu__link" role="menuitem">Courier Jobs</a></li><li class="menu__item"><a href="https://www.monster.com/jobs/q-delivery-driver-jobs.aspx" class="menu__link" role="menuitem">Delivery Driver Jobs</a></li><li class="menu__item"><a href="https://www.monster.com/jobs/q-dental-assistant-jobs.aspx" class="menu__link" role="menuitem">Dental Assistant Jobs</a></li><li class="menu__item"><a href="https://www.monster.com/jobs/q-electrician-jobs.aspx" class="menu__link" role="menuitem">Electrician Jobs</a></li><li class="menu__item"><a href="https://www.monster.com/jobs/q-medical-assistant-jobs.aspx" class="menu__link" role="menuitem">Medical Assistant Jobs</a></li><li class="menu__item"><a href="https://www.monster.com/jobs/q-truck-driver-jobs.aspx" class="menu__link" role="menuitem">Truck Driver Jobs</a></li><li class="menu__item"><a href="https://www.monster.com/jobs/q-pharmacist-jobs.aspx" class="menu__link" role="menuitem">Pharmacist Jobs</a></li><li class="menu__item"><a href="https://www.monster.com/jobs/q-pharmacy-technician-jobs.aspx" class="menu__link" role="menuitem">Pharmacy Technician Jobs</a></li><li class="menu__item"><a href="https://www.monster.com/jobs/q-receptionist-jobs.aspx" class="menu__link" role="menuitem">Receptionist Jobs</a></li><li class="menu__item"><a href="https://www.monster.com/jobs/q-security-guard-jobs.aspx" class="menu__link" role="menuitem">Security Guard Jobs</a></li></ul><ul data-menu="submenu-1" class="menu__level">
#
#     <li id="mobile-subnav-2" class="menu__item">
#         <a class="menu__link" href="https://www.monster.com/career-advice" role="menuitem">Career Advice</a>
#     </li>
#     <li id="mobile-subnav-3" class="menu__item">
#         <a class="menu__link" href="https://www.monster.com/salary" role="menuitem">Salary</a>
#     </li>
#     <li id="mobile-subnav-4" class="menu__item">
#         <a class="menu__link" href="http://career-services.monster.com/" role="menuitem">Career Services</a>
#     </li>
#     <li id="mobile-subnav-5" class="menu__item">
#         <a class="menu__link" href="https://www.monster.com/communities" role="menuitem">Communities</a>
#     </li>
#     <li id="mobile-subnav-6" class="menu__item">
#         <a class="menu__link" href="https://www.monster.com/career-advice/news" role="menuitem">Employment News</a>
#     </li>
#     <li id="mobile-subnav-" class="menu__item">
#         <a class="menu__link" data-submenu="submenu-cms-165" href="#" aria-haspopup="true" aria-expanded="false" role="menuitem">Additional Resources</a>
#
#     </li>
#
#                                         </ul><ul data-menu="submenu-cms-165" data-sub-for="165" class="menu__level cms-submenu">
#
#
#         <li class="menu__item"><a href="https://www.monster.com/career-advice/cover-letter-resume" class="menu__link" role="menuitem">Cover Letters &amp; Resumes</a></li><li class="menu__item"><a class="ext menu__link" href="https://www.monster.com/career-advice/job-interview" role="menuitem">Interviewing Tips</a></li><li class="menu__item"><a href="https://www.monster.com/career-advice/salary-benefits" class="menu__link" role="menuitem">Salary &amp; Benefits</a></li><li class="menu__item"><a href="https://www.monster.com/career-advice/career-path" class="menu__link" role="menuitem">Career Paths</a></li><li class="menu__item"><a href="https://www.monster.com/career-advice/workplace" class="menu__link" role="menuitem">Workplace Advice</a></li><li class="menu__item"><a href="https://www.monster.com/career-advice/professional-development" class="menu__link" role="menuitem">Professional Development</a></li><li class="menu__item"><a href="http://resources.monster.com/diversity-inclusion/work/" class="menu__link" role="menuitem">Diversity Resources</a></li></ul></div>
#                 </nav>
#             </div>
#             <!-- End Main Container for Mobile Main Nav -->
#
#         </nav>
#     <!-- End Navbar Fixed Top -->
#     <!-- Nav Modal End -->
# </div>
#
#
#
#
# <script type="text/javascript">
#
#     $(function () {
#
#         $('li.twocolumnslink &gt; a').on('click',
#             function (event) {
#                 var parentLi = $(this).parent();
#
#                 if ($(this).parent().attr('class').indexOf("twocolumnslink-close") != -1) {
#                     parentLi.removeClass('twocolumnslink-close').addClass('twocolumnslink-open');
#                 } else {
#                     parentLi.removeClass('twocolumnslink-open').addClass('twocolumnslink-close');
#                 }
#             });
#
#         //Sub-Menu Mobile
#         var $mlSubMenus = $('#ml-menu-container ul[data-menu*="submenu-"]');
#         if ($mlSubMenus.length) {
#             $mlSubMenus.each(function () {
#                 $(this).appendTo('#ml-menu-container');
#             });
#         }
#
#         //CMS Desktop
#         var $cmsNavContainers = $("li[id*='main-nav-'] div.cmsNavContainer");
#         if ($cmsNavContainers.length) {
#             for (var i = 0; i &lt; $cmsNavContainers.length; i++) {
#                 var $this = $($cmsNavContainers[i]);
#                 $this.addClass('hidden');
#                 var title = $this.find('h3').html();
#                 var $childs = $this.find('ul li');
#
#                 var $parentUl = $this.closest('ul');
#                 $parentUl.append('&lt;li class="cmsNavContainer dropdown-sub"&gt;&lt;/li&gt;');
#                 var $newCmsContainer = $parentUl.find('li.cmsNavContainer.dropdown-sub');
#                 $newCmsContainer.append('&lt;a href="#" class="dropdown-toggle" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false"&gt;' + title + ' &lt;span class="caret"&gt;&lt;/span&gt;&lt;/a&gt;');
#                 $newCmsContainer.append('&lt;ul class="dropdown-menu dropdown-menu-sub"&gt;&lt;/ul&gt;');
#                 $newCmsContainer.find('ul').append($childs);
#
#                 $this.remove();
#             }
#         }
#
#         //CMS Mobile
#         var $mobileCmsNavContainers = $("#ml-menu-container ul.cms-submenu div.cmsNavContainer");
#         if ($mobileCmsNavContainers.length) {
#             for (var i = 0; i &lt; $mobileCmsNavContainers.length; i++) {
#                 var $this = $($mobileCmsNavContainers[i]);
#                 var $parentUl = $this.closest('ul.cms-submenu');
#
#                 $this.addClass('hidden');
#                 var thisTitle = $this.find('h3').html();
#                 var $thisChilds = $this.find('ul li');
#
#                 var dataMenu = $parentUl.attr('data-menu');
#                 var dataSubFor = $parentUl.attr('data-sub-for');
#
#                 $thisChilds.each(function () {
#                     $(this).addClass('menu__item');
#                     $(this).find('a').addClass('menu__link');
#                     $(this).find('a').attr('role', 'menuitem');
#                 });
#
#                 $thisChilds.appendTo($parentUl);
#                 $this.remove();
#
#                 var $subLinkAnchor = $("#ml-menu-container a.menu__link[data-submenu='submenu-cms-" + dataSubFor + "']");
#                 if ($subLinkAnchor.length) {
#                     $subLinkAnchor.html(thisTitle);
#                 }
#             }
#         }
#
#         $('#mobile-navbar button[aria-expanded]').on('click', function () {
#             var $this = $(this);
#             var dataTargetMenuId = $this.attr('data-target-menu');
#             var targetIsNavCollapsed = $('#' + dataTargetMenuId).hasClass('navbar-collapse');
#
#             if (dataTargetMenuId != null &amp;&amp; dataTargetMenuId != '') {
#                 setTimeout(function () {
#                     var menuIsOpen = false;
#                     if (targetIsNavCollapsed) {
#                         menuIsOpen = $('#' + dataTargetMenuId).hasClass('collapse in');
#                     } else {
#                         menuIsOpen = $('#' + dataTargetMenuId).hasClass('menu--open');
#                     }
#                     $this.attr('aria-expanded', menuIsOpen);
#                 }, 200);
#             }
#         });
#
#         $('#ml-menu a[aria-expanded]').on('click', function () {
#             $(this).attr('aria-expanded', true);
#         });
#
#         setTimeout(function () {
#             globalHeaderNavigation({"BreadcrumbAriaLabel":"Navigation Breadcrumb","InitialBreadcrumbText":"all"});
#         }, 300);
#     });
#
#     $(document).ready(function () {
#
#         var isUsingAppDomainForServices = false;
#         if ('False' === 'True') {
#             isUsingAppDomainForServices = true;
#         }
#
#         InitializeHeaderBarJsr(isUsingAppDomainForServices); // all header related script
#     });
# </script>
#
#
#
#
#         </div>
#
#     <!--SecondaryNavigation-->
#
# <div class="mux-secondary-navigation">
#     <div class="navigation-content">
#         <span></span>
#
#
#
# <input type="hidden" id="filterSearchUrl" value="q=data-analyst&amp;pg=6&amp;intcid=skr_navigation_nhpso_searchMain&amp;stpage=1" />
# <input type="hidden" id="evar63Json" value="{&quot;company&quot;: [&quot;&quot;],&quot;category&quot;: [&quot;&quot;],&quot;kywdjobtitle&quot;: [&quot;data analyst&quot;],&quot;location&quot;: [&quot;&quot;],&quot;skill&quot;: [&quot;&quot;],&quot;jobstatus&quot;: [&quot;&quot;],&quot;radius&quot;: [&quot;&quot;],&quot;sort&quot;: [&quot;&quot;],&quot;date&quot;: [&quot;&quot;],&quot;country&quot;: [&quot;&quot;],&quot;salary&quot;: [&quot;&quot;]}" />
#
# <div class="mux-flyout mux-filter is-active" id="filter-flyout">
#     <button id="filter-flyout" role="button" class="mux-btn btn-link btn-neat flyout-toggle" data-mux="dropdown" data-type="click" data-close="outside" data-dim-target="#mainContent" aria-haspopup="true" aria-expanded="false" mux1527325082940="0"><i class="icon icon-settings" aria-hidden="true"></i>Filter<i class="icon icon-arrow-down" aria-hidden="true"></i></button>
#     <div class="mux-card flyout-content" aria-labelledby="filter-flyout" data-area="dropdown">
#         <form class="card-content" action="#" id="filter-form" method="post" data-mux="filter" data-target="#filter-flyout" mux1527325082940="1">
#             <header class="card-header flex-row">
#                 <h2 class="title">Filter your search</h2>
#                 <button type="button" class="mux-close" data-area="close">
#                     <i class="icon icon-close" aria-hidden="true"></i>
#                     <span class="sr-only">Close</span>
#                 </button>
#             </header>
# <div class="row">                                 <div class="form-group col-sm-6">
#                                      <label for="FilterRadius" class="control-label">Radius:</label>
#                                          <select class="form-control" id="FilterRadius" name="FilterRadius" disabled=""></select>
#                                  </div>
#                                      <div class="form-group col-sm-6">
#                                          <label for="FilterCity" class="control-label">City:</label>
#                                          <select class="form-control" id="FilterCity" name="FilterCity" data-selector="cityFilterDd">
#                                              <option value="">All Cities</option>
#                                                  <option value="New-York__2c-NY">New York</option>
#                                                  <option value="Chicago__2c-IL">Chicago</option>
#                                                  <option value="Seattle__2c-WA">Seattle</option>
#                                                  <option value="Atlanta__2c-GA">Atlanta</option>
#                                                  <option value="San-Francisco__2c-CA">San Francisco</option>
#                                                  <option value="Washington__2c-DC">Washington</option>
#                                                  <option value="Boston__2c-MA">Boston</option>
#                                                  <option value="Charlotte__2c-NC">Charlotte</option>
#                                                  <option value="Tampa__2c-FL">Tampa</option>
#                                                  <option value="Houston__2c-TX">Houston</option>
#                                          </select>
#                                      </div>
# ...
#                     <dl class="header">
#                       <dt class="key">Posted</dt>
#                       <dd class="value">2 Days ago</dd>
#                     </dl>
#                   </section>
#                   <section class="summary-section">
#                     <dl class="header">
#                       <dt class="key text-muted">Reference code</dt>
#                       <dd class="value text-muted">2280c6b0367df693344caa62605cdc1a</dd>
#                     </dl>
#                   </section>
#                 </div>
#               </div>
#             </div>
#           </div>
#         </div>
#       </div>
#     </div>
#     <div role="tabpanel" class="tab-pane" id="tab-company">
#       <div class="mux-card">
#         <div class="card-content">
#           <div class="mux-about-company" id="AboutCompany">
#             <div class="flex-row">
#             </div>
#             <div id="AboutCompanyTitle">CHRISTUS Health</div>
#             <div id="AboutCompanyDescription"></div>
#
#
#             <footer class="card-footer">
#               <dl class="meta list-value-accent">
#               </dl>
#             </footer>
#           </div>
#         </div>
#       </div>
#     </div>
#     <div role="tabpanel" class="tab-pane" id="tab-reviews">
#       <div id="kununu-reviews" class="mux-company-reviews wide" data-mux="companyReviews" data-apiurl="https://www.monster.com/reviews/api/reviews/getreviews" data-channel-id="58" data-company-xcode="" mux1527325083096="10">
#         <div class="mux-card">
#           <div class="card-content">
#             <header class="card-header">
#               <h2 class="title">Most recent reviews</h2>
#             </header>
#             <div data-content="stars-extend"></div>
#           </div>
#         </div>
#       </div>
#     </div>
#   </div>
# </div>
# <form id="BodyCaoModal" action="https://job-openings.monster.com/v2/subscription/CaoSubscribe" method="post" tabindex="-1" role="dialog" class="mux-cao-subscribe mux-modal fade" data-mux="validate caoSubscribe" data-apply="https://careers.christushealth.org/job-details/business-data-analyst-rehab-5000371502306-external/?utm_campaign=Monster" data-trigger="#PrimaryJobApply" data-email-input="#BodyCaoEmailAddress" data-at-jobapplytypeavailable="App_Cstm" data-jobapplyattribute="N/A-Cloud" data-jobapplypagetype="U/L-Apply" data-bypass="true" data-jobdetails-element="#JobBody" data-jobid="401459ea-3053-4b7d-9bfd-925f185ef2fc" mux1527325083096="13" novalidate="novalidate">
# <input type="hidden" name="JobID" value="401459ea-3053-4b7d-9bfd-925f185ef2fc" />
# <div class="modal-dialog">
#   <div class="modal-content">
#     <div class="modal-header">
#       <button type="button" class="mux-close" data-dismiss="modal">
#         <i class="icon icon-close" aria-hidden="true"></i>
#         <span class="sr-only">Close</span>
#       </button>
#       <h3 class="section-header">To begin the application process, please provide your email address</h3>
#     </div>
#     <div class="modal-body">
#       <div class="form-section form-inline">
#         <div class="form-group">
#           <label for="BodyCaoEmailAddress" class="sr-only">Email Address</label>
#           <input maxlength="100" class="form-control" id="BodyCaoEmailAddress" name="EmailAddress" placeholder="Your email address" type="email" data-msg-email="Email is not valid" value="" />
#         </div>
#         <button id="BodyCaoApply" type="submit" class="mux-btn btn-primary" data-at="apply" data-at-type="customapplyonline" role="button">Continue to Apply<i class="icon icon-external"></i></button>
#       </div>
#       <span class="small text-muted">By continuing you agree to Monster's <a target="_blank" href="undefined">Privacy Policy<i class="icon icon-external" aria-hidden="true"></i></a>, <a target="_blank" href="undefined">Terms of Use<i class="icon icon-external" aria-hidden="true"></i></a> and <a target="_blank" href="undefined">use of cookies<i class="icon icon-external" aria-hidden="true"></i></a>.</span>
#     </div>
#   </div>
# </div>
# </form>
# <script type="application/json" id="captcha-template-config">
#     {
#     "id": "captcha",
#     "lang": "en",
#     "siteKey": "6LfFxwwUAAAAAMb6IoJnE8q_cXbSoevLAyBTx8Pd",
#     "showHiddenField": true,
#     "hiddenFieldId": "CaptchaValue",
#     "apiUrl": "https://www.google.com/recaptcha/api.js?hl=en&amp;render=explicit"
#     }
# </script>
# <form id="emailFriendModal" method="post" action="https://job-openings.monster.com/v2/job/sendemailfriend" class="mux-email-form mux-modal fade" tabindex="-1" role="dialog" data-mux="validate emailForm" data-captcha-config="#captcha-template-config" data-trigger="#emailFriendOpen" data-success-msg="This job has been emailed to %email" data-email-input="#EmailAddressSendTo" data-captcha-template="captcha-template" data-captcha-placeholder="#captchaAnchor" data-enforce-captcha="true" mux1527325083096="15" novalidate="novalidate">
#     <input type="hidden" name="jobId" value="401459ea-3053-4b7d-9bfd-925f185ef2fc" />
#     <div class="modal-dialog">
#         <div class="modal-content">
#             <div class="modal-header">
#                 <button class="mux-close" data-dismiss="modal">
#                     <i class="icon icon-close" aria-hidden="true"></i>
#                     <span class="sr-only">Close</span>
#                 </button>
#                 <h3 class="section-header">Email this job</h3>
#             </div>
#             <div class="modal-body">
#                 <div class="form-section">
#                     <div class="form-group">
#                         <label for="EmailAddressSendFrom" class="sr-only">Your email
# </label>
#                         <input maxlength="100" class="form-control" id="EmailAddressSendFrom" name="SendFrom" placeholder="Your email&#10;" value="" data-msg-required="This information is required." data-msg-email="Email is not valid" required="" />
#                     </div>
#                     <div class="form-group">
#                         <label for="EmailAddressSendTo" class="sr-only">Email to send to</label>
#                         <input maxlength="100" class="form-control" id="EmailAddressSendTo" name="SendTo" placeholder="Email to send to" type="email" data-msg-required="This information is required." data-msg-email="Email is not valid" required="" />
#                     </div>
#                     <script type="text/x-placeholder" id="captchaAnchor">
#                     </script><label for="g-recaptcha-response" class="sr-only"></label>
# <div class="mux-captcha" data-mux="captcha" data-api-url="https://www.google.com/recaptcha/api.js?hl=en&amp;render=explicit" data-site-key="6LfFxwwUAAAAAMb6IoJnE8q_cXbSoevLAyBTx8Pd" data-field="#CaptchaValue" mux1527325083096="16"><div style="width: 304px; height: 78px;"><div><iframe src="https://www.google.com/recaptcha/api2/anchor?ar=1&amp;k=6LfFxwwUAAAAAMb6IoJnE8q_cXbSoevLAyBTx8Pd&amp;co=aHR0cHM6Ly93d3cubW9uc3Rlci5jb206NDQz&amp;hl=en&amp;v=v1526884278587&amp;size=normal&amp;cb=fvqoge8e8wkw" width="304" height="78" role="presentation" frameborder="0" scrolling="no" sandbox="allow-forms allow-popups allow-same-origin allow-scripts allow-top-navigation allow-modals allow-popups-to-escape-sandbox"></iframe></div><textarea id="g-recaptcha-response" name="g-recaptcha-response" class="g-recaptcha-response" style="width: 250px; height: 40px; border: 1px solid #c1c1c1; margin: 10px 25px; padding: 0px; resize: none;  display: none; "></textarea></div></div>
#   <input type="hidden" name="CaptchaValue" id="CaptchaValue" value="" required="" />
#                 </div>
#                 <p id="EmailAddressHelp" class="small text-muted">Note: Email addresses will only be used for mail delivery of this job.</p>
#             </div>
#             <div class="modal-footer">
#                 <button type="submit" class="mux-btn btn-primary">Email this job</button>
#             </div>
#         </div>
#     </div>
# </form></div>
#
#
#
#
#
# <footer id="PageFooter" role="contentinfo" class="mux-page-footer">
#     <div class="footer-content">
#         <a href="https://www.monster.com" class="home"><i class="monster-logo-abbr"></i><span class="sr-only">CareerOne</span></a>
#         <div class="legal-nav">
#             <small class="copyright">Copyright © 2016 | Monster Worldwide</small>
#             <small class="patents">U.S. Patents No. 7,599,930 B1; 7,827,125 and 7,836,060</small>
#             <small class="affiliates"></small>
#         </div>
#     </div>
# </footer>
#
#
#                             </div>
#                         <div class="scrollbar">
#   <div class="slider" style="height: 3602.27px; top: 0px;"></div>
# </div></div>
#                     </div>
#                 </div>
#                 <div class="dimmed-only"></div>
#             </main>
#         </div>
#     </div>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <script src="https://logs.jobs.com/coreTrackFP" type="text/javascript"></script><script src="https://logs.jobs.com/coreTrack" type="text/javascript"></script><script>coretrack.init('legacy=true,ImpressionStore=true');</script>
#
#     <div class="hide">
#
#
# <script id="mww_icp_tracking" type="text/javascript" async="true" src="//media.newjobs.com/mm/rainbow/tracking/scripts/Icp/IdentityTracking.js?v=4554502"></script>
#
#
# <div style="display:none;"></div>
#
#
#
#
#
#
#
#     </div>
#
#
# <div style="display: none; visibility: hidden;"><script>var pathname=window.location.pathname.toLowerCase();("/jobs/l-berlin.aspx"==pathname.substr(0,pathname.length)||-1&lt;window.location.href.indexOf("-l-berlin.aspx"))&amp;&amp;$('link[rel\x3d"canonical"]').attr("href","http://www.monster.de/jobs/l-berlin,-berlin.aspx");("/jobs/l-hamburg,-hamburg.aspx"==pathname.substr(0,pathname.length)||-1&lt;window.location.href.indexOf("-l-hamburg.aspx"))&amp;&amp;$('link[rel\x3d"canonical"]').attr("href","http://www.monster.de/jobs/l-hamburg.aspx");
# ("/jobs/l-bremen.aspx"==pathname.substr(0,pathname.length)||-1&lt;window.location.href.indexOf("-l-bremen.aspx"))&amp;&amp;$('link[rel\x3d"canonical"]').attr("href","http://www.monster.de/jobs/l-bremen,-bremen.aspx");("/jobs/l-brandenburg.aspx"==pathname.substr(0,pathname.length)||-1&lt;window.location.href.indexOf("-l-brandenburg.aspx"))&amp;&amp;$('link[rel\x3d"canonical"]').attr("href","http://www.monster.de/jobs/l-brandenburg,-brandenburg.aspx");
# ("/jobs/l-london.aspx"==pathname.substr(0,pathname.length)||-1&lt;window.location.href.indexOf("-l-london.aspx"))&amp;&amp;$('link[rel\x3d"canonical"]').attr("href","http://www.monster.co.uk/jobs/l-london,-london.aspx");("/vacatures/l-groningen.aspx"==pathname.substr(0,pathname.length)||-1&lt;window.location.href.indexOf("-l-groningen.aspx"))&amp;&amp;$('link[rel\x3d"canonical"]').attr("href","http://www.monsterboard.nl/vacatures/l-groningen,-groningen.aspx");
# ("/jobb/l-stockholm,-stockholms-l%C3%A4n.aspx"==pathname.substr(0,pathname.length)||-1&lt;window.location.href.indexOf("-l-stockholm,-stockholms-l%C3%A4n.aspx"))&amp;&amp;$('link[rel\x3d"canonical"]').attr("href","hhttp://www.monster.se/jobb/l-stockholms-l%C3%A4n.aspx");("/jobb/l-uppsala-l%C3%A4n.aspx"==pathname.substr(0,pathname.length)||-1&lt;window.location.href.indexOf("-l-uppsala-l%C3%A4n.aspx"))&amp;&amp;$('link[rel\x3d"canonical"]').attr("href","http://www.monster.se/jobb/l-uppsala,-uppsala-l%C3%A4n.aspx");
# ("/jobb/l-kalmar,-kalmar-l%C3%A4n.aspx"==pathname.substr(0,pathname.length)||-1&lt;window.location.href.indexOf("-l-kalmar,-kalmar-l%C3%A4n.aspx"))&amp;&amp;$('link[rel\x3d"canonical"]').attr("href","http://www.monster.se/jobb/l-kalmar-l%C3%A4n.aspx");("/jobb/l-%C3%B6rebro,-%C3%B6rebro.aspx"==pathname.substr(0,pathname.length)||-1&lt;window.location.href.indexOf("-l-%C3%B6rebro,-%C3%B6rebro.aspx"))&amp;&amp;$('link[rel\x3d"canonical"]').attr("href","http://www.monster.se/jobb/l-%C3%B6rebro.aspx");
# ("/jobb/l-j%C3%B6nk%C3%B6ping,-j%C3%B6nk%C3%B6pings-l%C3%A4n.aspx"==pathname.substr(0,pathname.length)||-1&lt;window.location.href.indexOf("-l-j%C3%B6nk%C3%B6ping,-j%C3%B6nk%C3%B6pings-l%C3%A4n.aspx"))&amp;&amp;$('link[rel\x3d"canonical"]').attr("href","http://www.monster.se/jobb/l-j%C3%B6nk%C3%B6pings-l%C3%A4n.aspx");</script></div><script type="text/javascript" id="">$(document).ready(function(){$(".js_result_container.featured-ad.clearfix").each(function(){var a=$(this).find("img").attr("src");"undefined"!=typeof a&amp;&amp;-1!=a.toLowerCase().indexOf("/creatives/default/empty.gif")&amp;&amp;$(this).remove()});jQuery('#resultsWrapper img[src*\x3d"/Creatives/default/empty.gif"]').remove()});</script><style type="text/css">
#
# body.card-view-2 #resultsWrapper .js_result_container:hover .jobTitle a,
# body.card-view-2 .js_result_container:hover .jobTitle a {
#     text-decoration: underline;
# }
#
# body.card-view-2 .js_result_container {
#     cursor: pointer;
# }
#
# body.card-view-3 #resultsWrapper .js_result_container:hover .jobTitle a,
# body.card-view-3 .js_result_container:hover .jobTitle a {
#     text-decoration: underline;
# }
#
# body.card-view-3 .js_result_container {
#     cursor: pointer;
# }
#
# .saved-data .trump {
#   display: none;
# }
# </style><img src="//logs2.jobs.com/cloudapi/ps?a_affiliate_id=jobs&amp;dvfpid=128aeec99fa18eec7cb82184553c2129&amp;seekerData=null" width="1" height="1" border="0" alt="" /><iframe src="//servedby.flashtalking.com/container/9063;67938;7093;iframe/?spotName=Visit_tag&amp;cachebuster=436216275" height="1px" width="1px" style="display: none;"></iframe><iframe src="//poweredby.monster.com/container/8809;67937;7092;iframe/?spotName=Visit_tag_with_Adobe_ID_capture&amp;cachebuster=342834993&amp;U2=10159717637422987882702328904958391531" height="1px" width="1px" style="display: none;"></iframe><img alt="" style="display: none; width: 1px;" src="https://idsync.rlcdn.com/423396.gif?partner_uid=7524730924189351836" /><div style="background-color: #fff; border: 1px solid #ccc; box-shadow: 2px 2px 3px rgba(0, 0, 0, 0.2); position: absolute; left: 0px; top: -10000px; transition: visibility 0s linear 0.3s, opacity 0.3s linear; opacity: 0; visibility: hidden; z-index: 2000000000;"><div style="width: 100%; height: 100%; position: fixed; top: 0px; left: 0px; z-index: 2000000000; background-color: #fff; opacity: 0.05;  filter: alpha(opacity=5)"></div><div class="g-recaptcha-bubble-arrow" style="border: 11px solid transparent; width: 0; height: 0; position: absolute; pointer-events: none; margin-top: -11px; z-index: 2000000000;"></div><div class="g-recaptcha-bubble-arrow" style="border: 10px solid transparent; width: 0; height: 0; position: absolute; pointer-events: none; margin-top: -10px; z-index: 2000000000;"></div><div style="z-index: 2000000000; position: relative;"><iframe title="recaptcha challenge" src="https://www.google.com/recaptcha/api2/bframe?hl=en&amp;v=v1526884278587&amp;k=6LfFxwwUAAAAAMb6IoJnE8q_cXbSoevLAyBTx8Pd&amp;cb=58k0v5uij1ws#2hqk8tu8tag5" frameborder="0" scrolling="no" sandbox="allow-forms allow-popups allow-same-origin allow-scripts allow-top-navigation allow-modals allow-popups-to-escape-sandbox" name="2hqk8tu8tag5" style="width: 100%; height: 100%;"></iframe></div></div><iframe id="destination_publishing_iframe_monster_0" src="https://monster.demdex.net/dest4.html?d_nsid=0#https%3A%2F%2Fwww.monster.com%2Fjobs%2Fsearch%2F%3Fq%3Ddata-analyst%26intcid%3Dskr_navigation_nhpso_searchMain%26jobid%3D401459ea-3053-4b7d-9bfd-925f185ef2fc%26stpage%3D1%26page%3D6" style="display: none; width: 0px; height: 0px;"></iframe><script src="https://analytics.twitter.com/i/adsct?p_id=Twitter&amp;p_user_id=0&amp;txn_id=l4lbg&amp;tw_sale_amount=0&amp;tw_order_quantity=0&amp;tw_iframe_status=0&amp;tpx_cb=twttr.conversion.loadPixels&amp;tw_document_href=https%3A%2F%2Fwww.monster.com%2Fjobs%2Fsearch%2F%3Fq%3Ddata-analyst%26intcid%3Dskr_navigation_nhpso_searchMain%26jobid%3D401459ea-3053-4b7d-9bfd-925f185ef2fc%26stpage%3D1%26page%3D6" type="text/javascript"></script><img alt="" style="display:none;width:1px;" src="https://ib.adnxs.com/seg?member=827&amp;add=8802230,8802362,8802613,8802654,8802657,8802713,2808424,3189196,7082173" /></body></html>
